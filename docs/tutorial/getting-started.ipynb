# %% [markdown]
# # Getting started with Starling (ST)

# %%
import os
os.getcwd()
# Out:
# '/home/campbell/yulee/project/st/starling-main/docs/tutorial'

# %%
import sys
import pandas as pd
import anndata as ad

import torch
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import EarlyStopping #ModelCheckpoint

sys.path.append("../../") ## change this path according to the current working directory
#sys.path.append("../../github/starling/")
from starling import utility
from starling import starling

# %%
os.getcwd()
# Out:
# '/home/campbell/yulee/project/st/starling-main/docs/tutorial'

# %% [markdown]
# ## Setting seed for everything

# %%
pl.utilities.seed.seed_everything(10, workers=True)
# Out:
# Global seed set to 10
# 10

# %% [markdown]
# ## Loading annData objects

# %% [markdown]
# The example below runs Kmeans with 10 clusters read from "sample_input.h5ad" object.

# %%
adata = utility.init_clustering(ad.read_h5ad('sample_input.h5ad'), 'KM', k=10)

# %% [markdown]
# The utility.py provides an easy setup of GMM, KM (Kmeans) or PG (PhenoGraph), k can be omitted when PG is used.

# %% [markdown]
# ## Setting initializations

# %% [markdown]
# The example below uses defualt parameter settings based on benchmarking results (more details in manuscript).

# %%
st = starling.ST(adata)

# %% [markdown]
# A list of parameters are shown:
# - adata: annDATA object of the sample
# - dist_option (default: 'T'): T for Student-T (df=2) and N for Normal (Gaussian)
# - the proportion of anticipated segmentation error free cells (default: 0.6)
# - model_cell_size (default: 'Y'): Y for incoporating cell size in the model and N otherwise
# - cell_size_col_name (default: 'area'): area is the column name in anndata.obs dataframe
# - model_zplane_overlap (default: 'Y'): Y for modeling z-plane overlap when cell size is modelled and N otherwise
# Note: if the user sets model_cell_size = 'N', then model_zplane_overlap is ignored
# - model_regularizer (default: 1): Regularizier term impose on synthetic doublet loss (BCE)
# - learning_rate (default: 1e-3): The learning rate of ADAM optimizer for STARLING
#
# Equivalent as the above example:
# st = starling.ST(adata, 'T', 'Y', 'area', 'Y', 1, 1e-3)

# %% [markdown]
# ## Setting trainning log

# %% [markdown]
# Once training starts, a new directory 'log' will created.

# %%
## log training results via tensorboard
log_tb = TensorBoardLogger(save_dir = 'log')

# %% [markdown]
# One could view the training information via tensorboard. Please refer to torch lightning (https://lightning.ai/docs/pytorch/stable/api_references.html#profiler) for other possible loggers.

# %% [markdown]
# ## Setting early stopping criterion

# %%
## set early stopping criterion
cb_early_stopping = EarlyStopping(monitor = 'train_loss', mode = 'min', verbose = False)

# %% [markdown]
# Training loss is monitored.

# %% [markdown]
# ## Training Starling

# %%
## train ST
trainer = pl.Trainer(max_epochs = 100, accelerator = 'auto', devices = 'auto', deterministic = True, callbacks = [cb_early_stopping], logger=[log_tb])
trainer.fit(st)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type | Params
# ------------------------------
# ------------------------------
# 0         Trainable params
# 0         Non-trainable params
# 0         Total params
# 0.000     Total estimated model params size (MB)
# /home/campbell/yulee/.local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (27) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Epoch 0:  15%|█▍        | 4/27 [00:00<00:03,  6.04it/s, loss=88.2, v_num=5, train_loss_step=88.10]
# ../../starling/utility.py:226: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   ccmax = torch.combinations(psi).max(1).values
# Epoch 99: 100%|██████████| 27/27 [00:01<00:00, 24.90it/s, loss=58.4, v_num=5, train_loss_step=58.00, train_loss_epoch=58.40]

# %% [markdown]
# ## Retriving Starling results

# %%
## retrive starling results
st.result()

# %% [markdown]
# ## The information can be retrieved from the annData object.
#    - st.adata.varm['init_exp_centroids']      -- initial expression cluster centroids (P x C matrix)
#    - st.adata.varm['st_exp_centroids']        -- ST expression cluster centroids (P x C matrix)
#    - st.adata.uns['init_cell_size_centroids'] -- initial cell size centroids if STARLING models cell size
#    - st.adata.uns['st_cell_size_centroids']   -- initial & ST cell size centroids if ST models cell size
#    - st.adata.obsm['assignment_prob_matrix']  -- cell assignment probability (N x C maxtrix)
#    - st.adata.obsm['gamma_prob_matrix']       -- gamma probabilitiy of two cells (N x C x C maxtrix)
#    - st.adata.obs['doublet']                  -- doublet indicator
#    - st.adata.obs['doublet_prob']             -- doublet probabilities
#    - st.adata.obs['init_label']               -- initial assignments
#    - st.adata.obs['st_label']                 -- ST assignments
#    - st.adata.obs['max_assign_prob']          -- ST max probabilites of assignments
#       - N: # of cells; C: # of clusters; P: # of proteins

# %% [markdown]
# ## Saving the model

# %%
## st object can be saved
torch.save(st, 'model.pt')

# %% [markdown]
# model.pt will be saved in the same directory as this notebook.

# %% [markdown]
# ## Starling results are appended to the annData object

# %%
st.adata
# Out:
# AnnData object with n_obs × n_vars = 13685 × 24
#     obs: 'sample', 'id', 'x', 'y', 'area', 'area_convex', 'neighbor', 'init_label', 'st_label', 'doublet_prob', 'doublet', 'max_assign_prob'
#     uns: 'init_cell_size_centroids', 'init_cell_size_variances', 'st_cell_size_centroids'
#     obsm: 'assignment_prob_matrix', 'gamma_assignment_prob_matrix'
#     varm: 'init_exp_centroids', 'init_exp_variances', 'st_exp_centroids'

# %% [markdown]
# One could easily perform further analysis such as co-occurance, enrichment analysis and etc.

# %%
st.adata.obs
# Out:
#          sample     id           x           y  area  area_convex  neighbor  \
# 4_1           4      1    0.785714    7.785714    14           14         0
# 4_2           4      2    0.823529   22.294117    17           17         0
# 4_3           4      3    0.875000   79.500000    16           16         1
# 4_4           4      4    0.666667  270.500000    12           12         0
# 4_5           4      5    0.823529  279.294130    17           17         1
# ...         ...    ...         ...         ...   ...          ...       ...
# 4_13681       4  13681  997.769200  754.500000    26           26         0
# 4_13682       4  13682  998.153900  127.615390    13           13         0
# 4_13683       4  13683  998.153900  160.000000    13           13         1
# 4_13684       4  13684  997.580600  242.580640    31           33         1
# 4_13685       4  13685  997.947400  531.315800    19           19         1
#
#          init_label  st_label  doublet_prob  doublet  max_assign_prob
# 4_1               7         3      0.107680        0         0.892312
# 4_2               8         3      0.475209        0         0.418412
# 4_3               5         3      0.107942        0         0.892058
# 4_4               4         3      0.140917        0         0.856819
# 4_5               2         2      0.578934        1         0.356235
# ...             ...       ...           ...      ...              ...
# 4_13681           9         9      0.058607        0         0.941282
# 4_13682           4         4      0.091396        0         0.908604
# 4_13683           7         3      0.128414        0         0.871540
# 4_13684           9         9      0.136119        0         0.860448
# 4_13685           6         3      0.146431        0         0.849226
#
# [13685 rows x 12 columns]

# %% [markdown]
# Starling provides doublet probabilities and cell assignment if it were a singlet for each cell.

# %% [markdown]
# ## Showing initial expression centriods:

# %%
## initial expression centriods (p x c) matrix
pd.DataFrame(st.adata.varm['init_exp_centroids'], index=st.adata.var_names)
# Out:
#                       0          1           2           3          4  \
# SMA            0.720967   0.585027    0.801933    2.132250   0.492805
# ECadherin      0.877221   0.999570    1.463762    0.918666   5.105359
# Cytokeratin    9.933142  12.609383   14.818891    7.949757  63.817917
# HLADR        109.319489  99.347565   30.853996   20.089088  11.319593
# Vimentin     215.871140  65.165985  145.056137  591.789062  31.197891
# CD28           0.402611   0.431232    0.407054    0.194037   0.282477
# CD15           0.842164   2.414609    4.767142   11.917000  10.161815
# CD45RA        25.086103  20.061749   10.642691    6.086351   3.428966
# CD66b          0.290807   0.260315    0.388225    0.912257   0.646158
# CD20          48.427780  66.686539   14.879524    6.222989   5.205252
# CD68           1.694603   1.243553    2.258113    3.206442   1.551707
# CD4            2.697721   2.233573    3.172808    2.414251   1.594865
# CD8            1.599895   1.180723    2.693063    2.889706   1.115371
# CD11c          2.588791   2.449675    2.544403    1.523319  11.263179
# CD45RO        20.105927  21.653862   21.479342   15.831129  12.501137
# CD3            6.748784   6.234415   10.706174    7.621643   3.485489
# IFNg           6.104801   7.022253    4.902954    4.550390   3.685096
# TCF1           1.867155   2.235105    2.905997    2.414281   1.699015
# CD14           8.013767   8.626688    8.577503   13.618200   9.995063
# CD56          10.990927  11.072330   11.423715   11.328709  16.193933
# PD1            0.883473   2.228852    0.909479    0.498852   0.486882
# CD45           9.300665   9.233282    7.330790    5.723529   5.459373
# PNAd           0.611508   0.569547    0.629040    3.658433   0.584406
# CD31           2.264203   2.123259    2.273990    4.095117   2.530740
#
#                       5           6           7           8           9
# SMA            2.310254    1.535946    1.150474    1.693778    0.614030
# ECadherin      0.978423    0.888575    0.941698    0.886874    2.994359
# Cytokeratin    7.390986    8.085617    8.824631    8.109798   34.635605
# HLADR         17.104588   26.659348   22.432001   25.211506   19.767342
# Vimentin     834.506287  338.028870  243.142197  443.985291  149.811188
# CD28           0.129055    0.340027    0.387506    0.281240    0.162825
# CD15           8.310090    2.395725    2.642576    3.612238  157.945465
# CD45RA         4.584605    8.464054    8.875180    7.588144    5.590945
# CD66b          0.923219    0.395315    0.345415    0.506907    6.663888
# CD20           4.316024    8.634953    8.083755    7.648183   10.075335
# CD68           3.588933    2.827576    2.618598    2.957651    2.647555
# CD4            1.868164    3.396905    3.553944    3.072715    1.793301
# CD8            2.259625    3.587432    3.628186    3.328448    1.432441
# CD11c          1.209351    1.873044    1.686396    1.689845    6.681789
# CD45RO        11.606849   20.481880   21.095655   18.547832   22.630693
# CD3            5.725297   10.983911   12.181512    9.776255    4.263937
# IFNg           4.312307    4.689301    4.632582    4.627266    5.416450
# TCF1           1.912770    3.139421    3.552049    2.797540    1.643238
# CD14          17.518543   10.387183    9.338972   11.702088    7.489246
# CD56          11.821151   11.678336   11.440997   11.296023   14.453732
# PD1            0.452578    0.594606    0.632511    0.550605    0.441847
# CD45           4.877842    6.877288    7.042150    6.401639    8.557882
# PNAd           7.494723    0.863373    0.720543    1.423024    0.873548
# CD31           5.648933    2.656965    2.513560    2.980573    2.658129

# %% [markdown]
# There are 10 centroids since we set Kmeans (KM) as k = 10 earlier.

# %% [markdown]
# ## Showing Starling expression centriods:

# %%
## starling expression centriods (p x c) matrix
pd.DataFrame(st.adata.varm['st_exp_centroids'], index=st.adata.var_names)
# Out:
#                       0           1           2           3          4  \
# SMA            0.630584    0.625222    0.646329    0.925917   0.449863
# ECadherin      0.602780    0.684089    0.780165    0.797225   5.494092
# Cytokeratin    9.022430    9.632510    7.601309    6.805786  69.495041
# HLADR         57.801815   88.580734   19.923067   10.716701   8.128937
# Vimentin     193.365860  108.276184  294.296844  369.279358  29.048990
# CD28           0.243396    0.351867    0.419079    0.052022   0.244220
# CD15           0.417759    0.394474    0.551968    3.617295   7.300360
# CD45RA        15.071248   23.635565    7.468481    3.171324   1.456866
# CD66b          0.226182    0.196237    0.293509    0.311583   0.220635
# CD20          27.397152   58.756229    4.724949    2.366850   1.946522
# CD68           1.409146    0.872599    1.993390    2.035008   1.357472
# CD4            1.833841    1.581293    4.179116    0.972678   1.259929
# CD8            1.566826    0.676170    2.308415    0.899468   0.860680
# CD11c          1.371404    1.083709    1.343484    0.673973   9.535459
# CD45RO        15.533746   18.396233   22.606857    9.431560  10.347698
# CD3            7.128511    3.780581   14.337039    2.869289   1.883758
# IFNg           5.276063    6.654183    4.874170    3.618299   3.410232
# TCF1           1.663048    1.654967    3.167093    1.427229   1.462742
# CD14           6.633362    7.040881    9.529215   10.478936   9.940675
# CD56           8.058310    9.737422   11.126308    8.600612  16.772425
# PD1            0.447511    0.835786    0.550378    0.270824   0.310420
# CD45           7.049543    8.994970    7.624235    3.876386   5.114023
# PNAd           0.493381    0.550244    0.618574    0.804580   0.559087
# CD31           1.837322    2.093492    2.237621    2.767595   2.591997
#
#                       5           6           7           8           9
# SMA            2.793317    2.356341    1.781954    2.149641    0.532924
# ECadherin      1.108318    0.864519    1.710122    0.597689    3.270387
# Cytokeratin    8.927615    7.453179    7.341437    5.320751   35.020645
# HLADR         14.212717   21.098606   12.688202   13.499730   33.775150
# Vimentin     853.547791  377.023956  335.995605  268.646179  133.570007
# CD28           0.093331    0.274716    0.245859    0.164856    0.142304
# CD15          12.508798    1.981807    1.466862    2.848590  104.114830
# CD45RA         3.126213    6.561466    8.161564    4.676317    7.831636
# CD66b          0.996837    0.347522    0.310293    0.258991    4.287268
# CD20           2.971781    6.542570    5.003287    4.631355   13.386323
# CD68           3.038949    2.729642    4.235557    1.821450    2.198187
# CD4            1.313097    2.744770    1.991634    1.531126    1.956857
# CD8            1.858142    3.454843    2.272196    2.434775    1.014185
# CD11c          1.030045    1.521647    1.448513    0.817018    5.142614
# CD45RO        11.204749   17.001131   12.513293   10.532390   21.059816
# CD3            4.389711    9.262806    6.678578    5.888115    3.530533
# IFNg           4.630115    4.112705    4.234228    2.973345    5.632924
# TCF1           1.944265    2.626162    8.542650    1.474951    1.500581
# CD14          20.820816   11.670476   12.643318    8.319501    8.261827
# CD56          13.900631   12.311626   28.225315    6.379488   16.460983
# PD1            0.372169    0.470195    0.481574    0.286455    0.446787
# CD45           4.326418    5.756781    6.109314    3.886027    8.753448
# PNAd          13.119802    0.922379    0.662126    1.454199    0.660829
# CD31           9.179468    3.009155    5.162354    2.149831    2.665978

# %% [markdown]
# From here one could easily annotate cluster centriods to cell type.

# %% [markdown]
# ## Showing Assignment Distributions:

# %%
## assignment distributions (n x c maxtrix)
pd.DataFrame(st.adata.obsm['assignment_prob_matrix'], index = st.adata.obs.index)
# Out:
#                     0             1             2             3             4  \
# 4_1      3.783097e-10  1.870313e-08  7.454336e-06  8.923120e-01  1.673693e-07
# 4_2      2.253198e-09  8.602157e-05  1.062930e-01  4.184124e-01  2.296793e-08
# 4_3      1.567647e-15  6.495662e-16  1.818553e-10  8.920578e-01  1.923190e-11
# 4_4      3.224672e-09  3.656452e-07  1.963687e-03  8.568190e-01  2.996252e-04
# 4_5      2.961560e-06  6.342213e-08  3.562353e-01  6.477993e-02  4.144526e-07
# ...               ...           ...           ...           ...           ...
# 4_13681  2.557147e-18  3.785219e-15  2.366307e-13  4.329301e-08  1.110778e-04
# 4_13682  1.904857e-13  3.979871e-13  1.681163e-10  2.300984e-10  9.086042e-01
# 4_13683  3.569051e-12  7.494605e-08  4.569505e-05  8.715396e-01  2.190433e-07
# 4_13684  1.515786e-15  2.098635e-13  6.944415e-10  1.426281e-08  3.433115e-03
# 4_13685  5.134009e-09  1.016957e-05  3.939170e-03  8.492255e-01  3.937906e-04
#
#                     5             6             7             8             9
# 4_1      3.145988e-17  4.585031e-16  1.625775e-15  3.954680e-11  2.633352e-12
# 4_2      3.368046e-15  9.210434e-12  3.308265e-11  5.122466e-10  6.382439e-10
# 4_3      1.889954e-08  2.455403e-15  1.051328e-13  5.568968e-11  3.372012e-12
# 4_4      1.629633e-14  1.802143e-14  3.459486e-15  3.711590e-10  3.037263e-10
# 4_5      1.328070e-12  6.870071e-09  1.043632e-09  4.769265e-05  4.274003e-13
# ...               ...           ...           ...           ...           ...
# 4_13681  4.569230e-16  4.551192e-18  3.977166e-16  1.793794e-14  9.412823e-01
# 4_13682  7.093535e-21  9.250489e-19  8.101208e-17  3.967741e-17  8.297649e-09
# 4_13683  7.166176e-16  1.738358e-16  1.070137e-17  3.586017e-12  7.725170e-12
# 4_13684  2.658963e-17  1.186033e-18  1.115595e-17  1.341295e-14  8.604477e-01
# 4_13685  4.940976e-12  4.946697e-12  3.101810e-09  6.510191e-11  7.464429e-10
#
# [13685 rows x 10 columns]

# %% [markdown]
# Currently, we assign a cell label based on the maximum probability among all possible clusters. However, there could be mislabeled because maximum and second highest probabilies can be very close that the user might be interested.
